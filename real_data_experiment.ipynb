# %%
import pickle
from src.data import get_real_datasets
from src.models import get_models
from src.utils import run_prequential_eval

# %%
INSTANCES = 10_000

# %% [markdown]
# ### GRADUAL - Hyperplane + Friedman Datasets

# %%
test_datasets = get_real_datasets()
models = get_models()

# %%
logs = run_prequential_eval(models, test_datasets, INSTANCES)
with open("./logs/real.pkl", "wb") as file:
    pickle.dump(logs, file)
# Out:
# Evaluating HATR (baseline) on ailerons
# Final RMSE: 0.000196: 0.000196
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on ailerons
# Final RMSE: 0.000201: 0.000201
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on ailerons
# Final RMSE: 0.000194: 0.000194
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on ailerons
# Final RMSE: 0.000192: 0.000192
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on ailerons
# Final RMSE: 0.000192: 0.000192
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on ailerons
# Final RMSE: 0.000191: 0.000191
# --------------------------------------------------
# Evaluating HATR (baseline) on airquality
# Final RMSE: 88.912479: 88.912479
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on airquality
# Final RMSE: 75.426648: 75.426648
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on airquality
# Final RMSE: 75.426648: 75.426648
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on airquality
# Final RMSE: 75.426648: 75.426648
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on airquality
# Final RMSE: 75.426648: 75.426648
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on airquality
# Final RMSE: 75.426648: 75.426648
# --------------------------------------------------
# Evaluating HATR (baseline) on abalone
# Final RMSE: 2.008823: 2.008823
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on abalone
# Final RMSE: 2.024018: 2.024018
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on abalone
# Final RMSE: 2.000154: 2.000154
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on abalone
# Final RMSE: 2.022434: 2.022434
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on abalone
# Final RMSE: 2.022434: 2.022434
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on abalone
# Final RMSE: 2.031568: 2.031568
# --------------------------------------------------
# Evaluating HATR (baseline) on wine
# Final RMSE: 0.77771: 0.777710
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on wine
# Final RMSE: 0.794245: 0.794245
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on wine
# Final RMSE: 0.791948: 0.791948
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on wine
# Final RMSE: 0.794255: 0.794255
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on wine
# Final RMSE: 0.793591: 0.793591
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on wine
# Final RMSE: 0.793674: 0.793674
# --------------------------------------------------
# Evaluating HATR (baseline) on california_housing
# Final RMSE: 0.627283: 0.627283
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on california_housing
# Final RMSE: 0.676631: 0.676631
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on california_housing
# Final RMSE: 0.687468: 0.687468
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on california_housing
# Final RMSE: 0.596335: 0.596335
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on california_housing
# Final RMSE: 0.60325: 0.603250
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on california_housing
# Final RMSE: 0.606652: 0.606652
# --------------------------------------------------
# Evaluating HATR (baseline) on bikes
# Final RMSE: 2.861634: 2.861634
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on bikes
# Final RMSE: 4.30172: 4.301720
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on bikes
# Final RMSE: 3.848136: 3.848136
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on bikes
# Final RMSE: 3.865657: 3.865657
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on bikes
# Final RMSE: 3.794854: 3.794854
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on bikes
# Final RMSE: 3.863638: 3.863638
# --------------------------------------------------
# Evaluating HATR (baseline) on elec2
# Final RMSE: 0.330714: 0.330714
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on elec2
# Final RMSE: 0.393302: 0.393302
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on elec2
# Final RMSE: 0.398129: 0.398129
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on elec2
# Final RMSE: 0.364999: 0.364999
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on elec2
# Final RMSE: 0.36339: 0.363390
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on elec2
# Final RMSE: 0.364619: 0.364619
# --------------------------------------------------
# Evaluating HATR (baseline) on covertype
# Final RMSE: 1.410941: 1.410941
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.25 (baseline) on covertype
# Final RMSE: 1.306363: 1.306363
# --------------------------------------------------
# Evaluating HTR-QO-radius 0.5 (baseline) on covertype
# Final RMSE: 1.348529: 1.348529
# --------------------------------------------------
# Evaluating HTR-AQO-Triangular-0.5 on covertype
# Final RMSE: 1.363287: 1.363287
# --------------------------------------------------
# Evaluating HTR-AQO-Epanechnikov-0.5 on covertype
# Final RMSE: 1.36316: 1.363160
# --------------------------------------------------
# Evaluating HTR-AQO-Smooth-0.5 on covertype
# Final RMSE: 1.346983: 1.346983
# --------------------------------------------------
