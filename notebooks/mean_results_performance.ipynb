# %%
try:
    from notebooks.bootstrap import ensure_src_importable
except ModuleNotFoundError:
    from bootstrap import ensure_src_importable

ensure_src_importable()

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from src.paths import resolve_repo_path
from src.utils import rank_logs
from src.stats import friedman_statistics, iman_davenport, eval_significance, critical_difference_nemenyi, critical_difference_bonferroni_dunn
from src.plot import draw_nemenyi_diagram, draw_bonferroni_dunn_diagram

# %%
with open(resolve_repo_path("logs/gradual.pkl"), "rb") as file:
    logs = pickle.load(file)

models = {log.model: 0 for log in logs}
synth_datasets = {log.dataset: 0 for log in logs}
N_MODELS = len(models)
N_DATASETS = len(synth_datasets)
print(f"""
MODELS: {N_MODELS}
N_DATASETS: {N_DATASETS}
""")
# Out:
# MODELS: 6
# N_DATASETS: 33

# %%
params = ["performance", "memory", "time"]
results = []
for param in params:
    friedman_matrix = rank_logs(logs, param, models.keys(), synth_datasets.keys())
    results.append(friedman_matrix.rank(axis=1, ascending=True, method="average").mean())

results = pd.DataFrame(results, index=params)
stats_results = results.copy()
stats_results["fried_stats"] = results.apply(lambda x: friedman_statistics(x, N_DATASETS), axis=1)
stats_results["iman_davenport"] = stats_results["fried_stats"].apply(lambda x: iman_davenport(x, N_DATASETS, N_MODELS))
stats_results["significant"] = stats_results["iman_davenport"].apply(lambda x: eval_significance(x, N_MODELS, N_DATASETS, 0.05))

# %%
avg_performance_results = rank_logs(logs, "performance", models.keys(), synth_datasets.keys()).rank(axis=1, ascending=True, method="average").round(4)
avg_performance_results
# Out:
#                                                     HATR (baseline)  \
# \n        RandomRBF\n        Seed Model = 168\n...              3.0
# \n        RandomRBF\n        Seed Model = 575\n...              5.0
# \n        RandomRBF\n        Seed Model = 386\n...              1.0
# \n        RandomRBF\n        Seed Model = 370\n...              5.0
# \n        RandomRBF\n        Seed Model = 489\n...              6.0
# \n        RandomRBF\n        Seed Model = 21\n ...              5.0
# \n        RandomRBF\n        Seed Model = 862\n...              6.0
# \n        RandomRBF\n        Seed Model = 65\n ...              6.0
# \n        RandomRBF\n        Seed Model = 324\n...              6.0
# \n        RandomRBF\n        Seed Model = 816\n...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              5.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Friedman\n        Drift = GSG\n      ...              6.0
# \n        Hyperplane\n        Seed = 159\n     ...              6.0
# \n        Hyperplane\n        Seed = 176\n     ...              6.0
# \n        Hyperplane\n        Seed = 139\n     ...              4.0
# \n        Hyperplane\n        Seed = 779\n     ...              4.0
# \n        Hyperplane\n        Seed = 114\n     ...              5.0
# \n        Hyperplane\n        Seed = 631\n     ...              3.0
# \n        Hyperplane\n        Seed = 652\n     ...              5.0
# \n        Hyperplane\n        Seed = 692\n     ...              5.0
# \n        Hyperplane\n        Seed = 817\n     ...              2.0
# \n        Hyperplane\n        Seed = 368\n     ...              6.0
# bikes                                                           1.0
# elec2                                                           5.0
# covertype                                                       6.0
#
#                                                     HTR-QO-0.25 (baseline)  \
# \n        RandomRBF\n        Seed Model = 168\n...                     1.0
# \n        RandomRBF\n        Seed Model = 575\n...                     4.0
# \n        RandomRBF\n        Seed Model = 386\n...                     6.0
# \n        RandomRBF\n        Seed Model = 370\n...                     1.0
# \n        RandomRBF\n        Seed Model = 489\n...                     2.0
# \n        RandomRBF\n        Seed Model = 21\n ...                     1.0
# \n        RandomRBF\n        Seed Model = 862\n...                     4.0
# \n        RandomRBF\n        Seed Model = 65\n ...                     4.0
# \n        RandomRBF\n        Seed Model = 324\n...                     4.0
# \n        RandomRBF\n        Seed Model = 816\n...                     3.0
# \n        Friedman\n        Drift = GSG\n      ...                     2.0
# \n        Friedman\n        Drift = GSG\n      ...                     2.0
# \n        Friedman\n        Drift = GSG\n      ...                     5.0
# \n        Friedman\n        Drift = GSG\n      ...                     2.0
# \n        Friedman\n        Drift = GSG\n      ...                     3.0
# \n        Friedman\n        Drift = GSG\n      ...                     4.0
# \n        Friedman\n        Drift = GSG\n      ...                     4.0
# \n        Friedman\n        Drift = GSG\n      ...                     4.0
# \n        Friedman\n        Drift = GSG\n      ...                     3.0
# \n        Friedman\n        Drift = GSG\n      ...                     4.0
# \n        Hyperplane\n        Seed = 159\n     ...                     5.0
# \n        Hyperplane\n        Seed = 176\n     ...                     3.0
# \n        Hyperplane\n        Seed = 139\n     ...                     6.0
# \n        Hyperplane\n        Seed = 779\n     ...                     5.0
# \n        Hyperplane\n        Seed = 114\n     ...                     6.0
# \n        Hyperplane\n        Seed = 631\n     ...                     6.0
# \n        Hyperplane\n        Seed = 652\n     ...                     6.0
# \n        Hyperplane\n        Seed = 692\n     ...                     6.0
# \n        Hyperplane\n        Seed = 817\n     ...                     6.0
# \n        Hyperplane\n        Seed = 368\n     ...                     5.0
# bikes                                                                  5.0
# elec2                                                                  3.0
# covertype                                                              2.0
#
#                                                     HTR-QO-0.5 (baseline)  \
# \n        RandomRBF\n        Seed Model = 168\n...                    2.0
# \n        RandomRBF\n        Seed Model = 575\n...                    6.0
# \n        RandomRBF\n        Seed Model = 386\n...                    4.0
# \n        RandomRBF\n        Seed Model = 370\n...                    6.0
# \n        RandomRBF\n        Seed Model = 489\n...                    5.0
# \n        RandomRBF\n        Seed Model = 21\n ...                    2.0
# \n        RandomRBF\n        Seed Model = 862\n...                    5.0
# \n        RandomRBF\n        Seed Model = 65\n ...                    5.0
# \n        RandomRBF\n        Seed Model = 324\n...                    5.0
# \n        RandomRBF\n        Seed Model = 816\n...                    5.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    2.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Friedman\n        Drift = GSG\n      ...                    1.0
# \n        Hyperplane\n        Seed = 159\n     ...                    4.0
# \n        Hyperplane\n        Seed = 176\n     ...                    5.0
# \n        Hyperplane\n        Seed = 139\n     ...                    3.0
# \n        Hyperplane\n        Seed = 779\n     ...                    2.0
# \n        Hyperplane\n        Seed = 114\n     ...                    4.0
# \n        Hyperplane\n        Seed = 631\n     ...                    5.0
# \n        Hyperplane\n        Seed = 652\n     ...                    1.0
# \n        Hyperplane\n        Seed = 692\n     ...                    4.0
# \n        Hyperplane\n        Seed = 817\n     ...                    3.0
# \n        Hyperplane\n        Seed = 368\n     ...                    4.0
# bikes                                                                 6.0
# elec2                                                                 2.0
# covertype                                                             1.0
#
#                                                     HTR-AQO-Triangular  \
# \n        RandomRBF\n        Seed Model = 168\n...                 6.0
# \n        RandomRBF\n        Seed Model = 575\n...                 3.0
# \n        RandomRBF\n        Seed Model = 386\n...                 3.0
# \n        RandomRBF\n        Seed Model = 370\n...                 4.0
# \n        RandomRBF\n        Seed Model = 489\n...                 4.0
# \n        RandomRBF\n        Seed Model = 21\n ...                 6.0
# \n        RandomRBF\n        Seed Model = 862\n...                 1.0
# \n        RandomRBF\n        Seed Model = 65\n ...                 1.0
# \n        RandomRBF\n        Seed Model = 324\n...                 2.0
# \n        RandomRBF\n        Seed Model = 816\n...                 1.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 2.0
# \n        Friedman\n        Drift = GSG\n      ...                 6.0
# \n        Friedman\n        Drift = GSG\n      ...                 4.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 5.0
# \n        Friedman\n        Drift = GSG\n      ...                 3.0
# \n        Hyperplane\n        Seed = 159\n     ...                 1.0
# \n        Hyperplane\n        Seed = 176\n     ...                 4.0
# \n        Hyperplane\n        Seed = 139\n     ...                 5.0
# \n        Hyperplane\n        Seed = 779\n     ...                 6.0
# \n        Hyperplane\n        Seed = 114\n     ...                 3.0
# \n        Hyperplane\n        Seed = 631\n     ...                 4.0
# \n        Hyperplane\n        Seed = 652\n     ...                 3.0
# \n        Hyperplane\n        Seed = 692\n     ...                 2.0
# \n        Hyperplane\n        Seed = 817\n     ...                 1.0
# \n        Hyperplane\n        Seed = 368\n     ...                 2.0
# bikes                                                              4.0
# elec2                                                              6.0
# covertype                                                          5.0
#
#                                                     HTR-AQO-Epanechnikov  \
# \n        RandomRBF\n        Seed Model = 168\n...                   4.0
# \n        RandomRBF\n        Seed Model = 575\n...                   2.0
# \n        RandomRBF\n        Seed Model = 386\n...                   5.0
# \n        RandomRBF\n        Seed Model = 370\n...                   2.0
# \n        RandomRBF\n        Seed Model = 489\n...                   3.0
# \n        RandomRBF\n        Seed Model = 21\n ...                   3.0
# \n        RandomRBF\n        Seed Model = 862\n...                   2.0
# \n        RandomRBF\n        Seed Model = 65\n ...                   3.0
# \n        RandomRBF\n        Seed Model = 324\n...                   3.0
# \n        RandomRBF\n        Seed Model = 816\n...                   2.0
# \n        Friedman\n        Drift = GSG\n      ...                   4.0
# \n        Friedman\n        Drift = GSG\n      ...                   4.0
# \n        Friedman\n        Drift = GSG\n      ...                   4.0
# \n        Friedman\n        Drift = GSG\n      ...                   4.0
# \n        Friedman\n        Drift = GSG\n      ...                   5.0
# \n        Friedman\n        Drift = GSG\n      ...                   3.0
# \n        Friedman\n        Drift = GSG\n      ...                   3.0
# \n        Friedman\n        Drift = GSG\n      ...                   2.0
# \n        Friedman\n        Drift = GSG\n      ...                   4.0
# \n        Friedman\n        Drift = GSG\n      ...                   5.0
# \n        Hyperplane\n        Seed = 159\n     ...                   3.0
# \n        Hyperplane\n        Seed = 176\n     ...                   1.0
# \n        Hyperplane\n        Seed = 139\n     ...                   1.0
# \n        Hyperplane\n        Seed = 779\n     ...                   1.0
# \n        Hyperplane\n        Seed = 114\n     ...                   2.0
# \n        Hyperplane\n        Seed = 631\n     ...                   1.0
# \n        Hyperplane\n        Seed = 652\n     ...                   2.0
# \n        Hyperplane\n        Seed = 692\n     ...                   1.0
# \n        Hyperplane\n        Seed = 817\n     ...                   5.0
# \n        Hyperplane\n        Seed = 368\n     ...                   1.0
# bikes                                                                3.0
# elec2                                                                4.0
# covertype                                                            3.0
#
#                                                     HTR-AQO-Smooth
# \n        RandomRBF\n        Seed Model = 168\n...             5.0
# \n        RandomRBF\n        Seed Model = 575\n...             1.0
# \n        RandomRBF\n        Seed Model = 386\n...             2.0
# \n        RandomRBF\n        Seed Model = 370\n...             3.0
# \n        RandomRBF\n        Seed Model = 489\n...             1.0
# \n        RandomRBF\n        Seed Model = 21\n ...             4.0
# \n        RandomRBF\n        Seed Model = 862\n...             3.0
# \n        RandomRBF\n        Seed Model = 65\n ...             2.0
# \n        RandomRBF\n        Seed Model = 324\n...             1.0
# \n        RandomRBF\n        Seed Model = 816\n...             4.0
# \n        Friedman\n        Drift = GSG\n      ...             3.0
# \n        Friedman\n        Drift = GSG\n      ...             3.0
# \n        Friedman\n        Drift = GSG\n      ...             3.0
# \n        Friedman\n        Drift = GSG\n      ...             3.0
# \n        Friedman\n        Drift = GSG\n      ...             2.0
# \n        Friedman\n        Drift = GSG\n      ...             1.0
# \n        Friedman\n        Drift = GSG\n      ...             2.0
# \n        Friedman\n        Drift = GSG\n      ...             3.0
# \n        Friedman\n        Drift = GSG\n      ...             2.0
# \n        Friedman\n        Drift = GSG\n      ...             2.0
# \n        Hyperplane\n        Seed = 159\n     ...             2.0
# \n        Hyperplane\n        Seed = 176\n     ...             2.0
# \n        Hyperplane\n        Seed = 139\n     ...             2.0
# \n        Hyperplane\n        Seed = 779\n     ...             3.0
# \n        Hyperplane\n        Seed = 114\n     ...             1.0
# \n        Hyperplane\n        Seed = 631\n     ...             2.0
# \n        Hyperplane\n        Seed = 652\n     ...             4.0
# \n        Hyperplane\n        Seed = 692\n     ...             3.0
# \n        Hyperplane\n        Seed = 817\n     ...             4.0
# \n        Hyperplane\n        Seed = 368\n     ...             3.0
# bikes                                                          2.0
# elec2                                                          1.0
# covertype                                                      4.0

# %%
import seaborn as sns

# %%
sns.boxplot(data=avg_performance_results, orient="y")
# Out:
# <Axes: >
